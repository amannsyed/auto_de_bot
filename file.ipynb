# %%
import pandas as pd

# %%
#import xlsx file as csv dataframe
df = pd.read_csv('TSDW FEE DATA- SE.csv', encoding='latin-1')
df
# Out:
#      ï»¿Roll No                Name   Phone Number                 E-Mail ID  \
# 0            1.0           ZAID KHAN  8.104140e+09  1032210447@tcetmumbai.in
# 1            2.0      SHAHAALAM KHAN  9.324717e+09  1032210448@tcetmumbai.in
# 2            3.0  CHIRAYU KHANDELWAL  9.850212e+09  1032210449@tcetmumbai.in
# 3            4.0       DINESH KHARAH  8.356899e+09  1032210450@tcetmumbai.in
# 4            5.0     DEEP KHASGIWALA  8.291522e+09  1032210451@tcetmumbai.in
# ..           ...                 ...           ...                       ...
# 994          NaN                 NaN           NaN                       NaN
# 995          NaN                 NaN           NaN                       NaN
# 996          NaN                 NaN           NaN                       NaN
# 997          NaN                 NaN           NaN                       NaN
# 998          NaN                 NaN           NaN                       NaN
#
# ...

# %%
# Select First name and Last name from the Name column
df['First Name'] = df['Name '].str.split(' ').str[0]
df['Last Name'] = df['Name '].str.split(' ').str[1]
df
# Out:
#      ï»¿Roll No                Name   Phone Number                 E-Mail ID  \
# 0            1.0           ZAID KHAN  8.104140e+09  1032210447@tcetmumbai.in
# 1            2.0      SHAHAALAM KHAN  9.324717e+09  1032210448@tcetmumbai.in
# 2            3.0  CHIRAYU KHANDELWAL  9.850212e+09  1032210449@tcetmumbai.in
# 3            4.0       DINESH KHARAH  8.356899e+09  1032210450@tcetmumbai.in
# 4            5.0     DEEP KHASGIWALA  8.291522e+09  1032210451@tcetmumbai.in
# ..           ...                 ...           ...                       ...
# 994          NaN                 NaN           NaN                       NaN
# 995          NaN                 NaN           NaN                       NaN
# 996          NaN                 NaN           NaN                       NaN
# 997          NaN                 NaN           NaN                       NaN
# 998          NaN                 NaN           NaN                       NaN
#
# ...

# %%
df.columns
# Out:
# Index(['ï»¿Roll No ', 'Name ', 'Phone Number', 'E-Mail ID', 'DIV ',
#        'Status Of TSDW Fee', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25'],
#       dtype='object')
